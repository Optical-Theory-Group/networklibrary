# %%
import os

import matplotlib.pyplot as plt
import numpy as np

from complex_network.networks import network_factory
from complex_network.networks.network_spec import NetworkSpec

# %%
np.random.seed(1)
k0 = 2*np.pi/(500e-9)
S_mat = np.array([[0.0, 1.0],[1.0, 0.0]])


spec = NetworkSpec(
    network_type="delaunay",
    network_shape="circular",
    num_seed_nodes=0,
    external_offset=0.0,
    num_internal_nodes=15,
    num_external_nodes=5,
    network_size=500e-6,
    external_size=550e-6,
    node_S_mat_type="COE",
    node_S_mat_params={},
)

network = network_factory.generate_network(spec)
network.draw(show_indices=True)
S1 = network.get_S_ee(k0)

# %%
A = network.get_node(8).get_S(1)
B= network.get_node(9).get_S(1)
C= network.get_node(13).get_S(1)

# %%
network.add_node_to_link(9, 0.5)
network.draw(show_indices=True)
S2 = network.get_S_ee(k0)
print(network.get_node(15).get_S(0))
print(network.get_link(33).get_S(k0))
print(network.get_link(34).get_S(k0))
# Out:
# [[0.+0.j 1.+0.j]
#  [1.+0.j 0.+0.j]]
# [[0.+0.j 1.+0.j]
#  [1.+0.j 0.+0.j]]
# [[0.+0.j 1.+0.j]
#  [1.+0.j 0.+0.j]]

# %%
A2 = network.get_node(8).get_S(1)
B2= network.get_node(9).get_S(1)
C2= network.get_node(13).get_S(1)
print(A-A2)
print("---")
print(B-B2)
print("---")
print(C-C2)
print("---")
# Out:
# [[0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]]
# ---
# [[0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]]
# ---
# [[ 0.        +0.j          0.        +0.j          0.        +0.j
#    0.        +0.j         -0.83587986-0.44672609j  0.26073852-0.14617634j
#    0.57514134+0.59290244j]
#  [ 0.        +0.j          0.        +0.j          0.        +0.j
#    0.        +0.j          0.24875311-0.45518214j  0.09353526+0.28815216j
#   -0.34228837+0.16702998j]
#  [ 0.        +0.j          0.        +0.j          0.        +0.j
#    0.        +0.j          0.21559103-0.4227696j  -0.39912907-0.00454075j
#    0.18353805+0.42731035j]
#  [ 0.        +0.j          0.        +0.j          0.        +0.j
#    0.        +0.j          0.05705857+0.15449289j -0.01228797-0.77900227j
#   -0.0447706 +0.62450938j]
#  [-0.83587986-0.44672609j  0.24875311-0.45518214j  0.21559103-0.4227696j
#    0.05705857+0.15449289j  0.09681457+0.06339525j -0.51614688+0.26428681j
#    0.00517041-0.02449197j]
#  [ 0.26073852-0.14617634j  0.09353526+0.28815216j -0.39912907-0.00454075j
#   -0.01228797-0.77900227j -0.51614688+0.26428681j  0.28077361+0.1708412j
#    0.51097647-0.23979484j]
#  [ 0.57514134+0.59290244j -0.34228837+0.16702998j  0.18353805+0.42731035j
#   -0.0447706 +0.62450938j  0.00517041-0.02449197j  0.51097647-0.23979484j
#   -0.37758818-0.23423645j]]
# ---

# %%
print(A)
# Out:
# [[-0.4415679 +0.10594775j -0.61135   -0.05859323j  0.36508266+0.36645269j
#    0.08451483+0.0342925j  -0.23059254+0.29588222j]
#  [-0.61135   -0.05859323j  0.35999616-0.23225918j  0.2652391 -0.07832123j
#    0.28132324-0.28819688j  0.42576914-0.13896361j]
#  [ 0.36508266+0.36645269j  0.2652391 -0.07832123j  0.14117695+0.73206707j
#    0.01906282-0.2655106j   0.16945399+0.0226723j ]
#  [ 0.08451483+0.0342925j   0.28132324-0.28819688j  0.01906282-0.2655106j
#    0.04233481-0.39564605j -0.41117198+0.65668209j]
#  [-0.23059254+0.29588222j  0.42576914-0.13896361j  0.16945399+0.0226723j
#   -0.41117198+0.65668209j -0.05910325+0.16023392j]]

# %%
print(A2)
# Out:
# [[-0.4415679 +0.10594775j -0.61135   -0.05859323j  0.36508266+0.36645269j
#    0.08451483+0.0342925j  -0.23059254+0.29588222j]
#  [-0.61135   -0.05859323j  0.35999616-0.23225918j  0.2652391 -0.07832123j
#    0.28132324-0.28819688j  0.42576914-0.13896361j]
#  [ 0.36508266+0.36645269j  0.2652391 -0.07832123j  0.14117695+0.73206707j
#    0.01906282-0.2655106j   0.16945399+0.0226723j ]
#  [ 0.08451483+0.0342925j   0.28132324-0.28819688j  0.01906282-0.2655106j
#    0.04233481-0.39564605j -0.41117198+0.65668209j]
#  [-0.23059254+0.29588222j  0.42576914-0.13896361j  0.16945399+0.0226723j
#   -0.41117198+0.65668209j -0.05910325+0.16023392j]]

# %%
print(S1)
print("---")
print(S2)
# Out:
# [[ 0.26562947+0.2391536j  -0.0649432 +0.41120461j  0.01938273+0.02518285j
#   -0.01732228+0.81768662j -0.04141491-0.16523666j]
#  [-0.0649432 +0.41120461j  0.20643084-0.80152034j -0.02543047-0.02984539j
#    0.12919957+0.33094143j  0.11784816+0.00204719j]
#  [ 0.01938273+0.02518285j -0.02543047-0.02984539j  0.09905489+0.90050033j
#   -0.00778019+0.04490402j -0.1107711 +0.40297993j]
#  [-0.01732228+0.81768662j  0.12919957+0.33094143j -0.00778019+0.04490402j
#    0.20325867-0.39431472j  0.056921  -0.05252311j]
#  [-0.04141491-0.16523666j  0.11784816+0.00204719j -0.1107711 +0.40297993j
#    0.056921  -0.05252311j  0.53661145-0.69891035j]]
# ---
# [[ 0.74195466-0.30892463j  0.00144639+0.15429661j -0.06535916+0.04582359j
#    0.31943436+0.45700177j -0.05764426-0.09836622j]
#  [ 0.00144639+0.15429661j  0.38548865-0.84452944j -0.04254737+0.13636477j
#    0.22674104+0.19016571j -0.06858967-0.04091845j]
#  [-0.06535916+0.04582359j -0.04254737+0.13636477j  0.0119023 +0.94013591j
#   -0.07771235+0.0949215j  -0.09966214+0.25346343j]
#  [ 0.31943436+0.45700177j  0.22674104+0.19016571j -0.07771235+0.0949215j
#    0.44952937-0.61851907j  0.00137104-0.04292903j]
#  [-0.05764426-0.09836622j -0.06858967-0.04091845j -0.09966214+0.25346343j
#    0.00137104-0.04292903j  0.71871158-0.6229406j ]]

# %%
network.add_node_to_link(9, 0.5)
network.draw(show_indices=True)
S3 = network.get_S_ee(k0)

# %%
network.add_node_to_link(32, 0.5)
network.draw(show_indices=True)
S4 = network.get_S_ee(k0)

# %%
network.add_node_to_link(0, 0.5)
network.draw(show_indices=True)
S5 = network.get_S_ee(k0)

# %%
for i in range(1000):
    network.add_node_to_link(0, 0.5)
S6 = network.get_S_ee(k0)
network.draw(show_indices=True)

# %%
print(np.min(S2 - S1))
print(np.min(S3 - S1))
print(np.min(S4 - S1))
print(np.min(S5 - S1))
print(np.min(S6 - S1))
# Out:
# (-0.18643783203311193-0.042965642375744996j)
# (-0.16591248239424483-0.05753962499003541j)
# (-0.16591248239424478-0.05753962499003549j)
# (-0.7845495000144865+0.24692546913890423j)
# (-0.6775783697626272-0.6615039732590668j)
